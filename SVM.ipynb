# %% [markdown]
# <a href="https://colab.research.google.com/github/mallavarapupranith05-a11y/MACHINE-LEARNING/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# **SVM ALGORITHM**
#
#
# ---
# ***24911A6698***
#
#
# ---
# ***CSE(AIML-B)***
#
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df =pd.read_csv ('/content/drive/MyDrive/iris.csv')

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df.species)
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df.species)
df['species'] =le.transform(df.species)
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
print(df.species)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
x=df.iloc[:,0:4]

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,4]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.70,random_state=42)

# %%
print(x_train.shape)
# Out:
# (45, 4)

# %%
print(x_test.shape)
# Out:
# (105, 4)

# %%
print(y_train.shape)
# Out:
# (45,)

# %%
print(y_test.shape)
# Out:
# (105,)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 6             4.6          3.4           1.4          0.3
# 112           6.8          3.0           5.5          2.1
# 100           6.3          3.3           6.0          2.5
# 2             4.7          3.2           1.3          0.2
# 63            6.1          2.9           4.7          1.4
# 54            6.5          2.8           4.6          1.5
# 126           6.2          2.8           4.8          1.8
# 50            7.0          3.2           4.7          1.4
# 115           6.4          3.2           5.3          2.3
# 46            5.1          3.8           1.6          0.2
# 139           6.9          3.1           5.4          2.1
# 61            5.9          3.0           4.2          1.5
# 147           6.5          3.0           5.2          2.0
# 79            5.7          2.6           3.5          1.0
# 59            5.2          2.7           3.9          1.4
# ...

# %%
y_train
# Out:
# 6      0
# 112    2
# 100    2
# 2      0
# 63     1
# 54     1
# 126    2
# 50     1
# 115    2
# 46     0
# 139    2
# 61     1
# 147    2
# 79     1
# 59     1
# 91     1
# 41     0
# 58     1
# 90     1
# 48     0
# 88     1
# 107    2
# 124    2
# 21     0
# 57     1
# 144    2
# 129    2
# 37     0
# 140    2
# 1      0
# 52     1
# 130    2
# 103    2
# 99     1
# 116    2
# 87     1
# 74     1
# 121    2
# 149    2
# 20     0
# 71     1
# 106    2
# 14     0
# 92     1
# 102    2
# Name: species, dtype: int64

# %%
model1 = SVC(C= .1,kernel='linear',gamma=1)

# %%
model1
# Out:
# SVC(C=0.1, gamma=1, kernel='linear')

# %%
model_train1 = model1.fit(x_train,y_train)

# %%
model_train1
# Out:
# SVC(C=0.1, gamma=1, kernel='linear')

# %%
y_pred1 =model_train1.predict(x_test)

# %%
y_pred1
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0,
#        1, 2, 0, 1, 2, 0, 1, 2, 1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 0,
#        0, 1, 1, 2, 2, 2, 2, 1, 0, 0, 1, 2, 0, 0, 0, 1, 2])

# %%
y_pred1[0:10]
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1])

# %%
print(y_test[:10])
# Out:
# 73     1
# 18     0
# 118    2
# 78     1
# 76     1
# 31     0
# 64     1
# 141    2
# 68     1
# 82     1
# Name: species, dtype: int64

# %%
i=0
print("\n------------------------------------------------------------------------")
print('%-25s %-25s %-25s' % ('Original Label', 'Predicted Label', 'Correct/Wrong'))
print("--------------------------------------------------------------------------")
for label in y_test:
  print('%-25s' '%-25s' % (label,y_pred1[i]), end=" ")
  if (label == y_pred1[i]):
    print(' %-25s' % ('Correct'))
  else:
    print(' %-25s' % ('Wrong'))
  i = i+1
print("--------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------------
# Original Label            Predicted Label           Correct/Wrong
# --------------------------------------------------------------------------
# 1                        1                          Correct
# 0                        0                          Correct
# 2                        2                          Correct
# 1                        1                          Correct
# 1                        1                          Correct
# 0                        0                          Correct
# 1                        1                          Correct
# 2                        2                          Correct
# 1                        1                          Correct
# 1                        1                          Correct
# 2                        2                          Correct
# 0                        0                          Correct
# ...

# %%
import sklearn.metrics as metrics
confusion = metrics.confusion_matrix (y_test,y_pred1)
confusion
# Out:
# array([[40,  0,  0],
#        [ 0, 31,  2],
#        [ 0,  2, 30]])

# %%
accuracy = accuracy_score(y_test,y_pred1)
accuracy
# Out:
# 0.9619047619047619

# %%
print('Accuracy of the classifier is %0.2f'%metrics.accuracy_score(y_test,y_pred1))
print("---------------------------------------------------------------------")
# Out:
# Accuracy of the classifier is 0.96
# ---------------------------------------------------------------------

# %%
print("\nClassification Report:\n",)
class_wise=metrics.classification_report(y_test,y_pred1)
print(class_wise)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       0.94      0.94      0.94        33
#            2       0.94      0.94      0.94        32
#
#     accuracy                           0.96       105
#    macro avg       0.96      0.96      0.96       105
# weighted avg       0.96      0.96      0.96       105

# %%
new_sample=[[5.1,3.5,1.4,0.2]]
prediction = model1.predict(new_sample)
predicted_label = le.inverse_transform(prediction)
print("Predicted Class =", predicted_label)
# Out:
# Predicted Class = ['setosa']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model2 = SVC(kernel='rbf')

# %%
model2
# Out:
# SVC()

# %%
model_train2 = model2.fit(x_train,y_train)

# %%
model_train2
# Out:
# SVC()

# %%
y_pred2 =model_train2.predict(x_test)

# %%
y_pred2
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0,
#        1, 2, 0, 1, 2, 0, 2, 2, 1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 0,
#        0, 2, 1, 2, 2, 2, 2, 1, 0, 0, 1, 2, 0, 0, 0, 1, 2])

# %%
i=0
print("\n------------------------------------------------------------------------")
print('%-25s %-25s %-25s' % ('Original Label', 'Predicted Label', 'Correct/Wrong'))
print("--------------------------------------------------------------------------")
for label in y_test:
  print('%-25s' '%-25s' % (label,y_pred2[i]), end=" ")
  if (label == y_pred2[i]):
    print(' %-25s' % ('Correct'))
  else:
    print(' %-25s' % ('Wrong'))
  i = i+1
print("--------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------------
# Original Label            Predicted Label           Correct/Wrong
# --------------------------------------------------------------------------
# 1                        1                          Correct
# 0                        0                          Correct
# 2                        2                          Correct
# 1                        1                          Correct
# 1                        1                          Correct
# 0                        0                          Correct
# 1                        1                          Correct
# 2                        2                          Correct
# 1                        1                          Correct
# 1                        1                          Correct
# 2                        2                          Correct
# 0                        0                          Correct
# ...

# %%
import sklearn.metrics as metrics
confusion = metrics.confusion_matrix (y_test,y_pred2)
confusion
# Out:
# array([[40,  0,  0],
#        [ 0, 30,  3],
#        [ 0,  1, 31]])

# %%
accuracy = accuracy_score(y_test,y_pred2)
accuracy
# Out:
# 0.9619047619047619

# %%
print('Accuracy of the classifier is %0.2f'%metrics.accuracy_score(y_test,y_pred2))
print("---------------------------------------------------------------------")
# Out:
# Accuracy of the classifier is 0.96
# ---------------------------------------------------------------------

# %%
print("\nClassification Report:\n",)
class_wise=metrics.classification_report(y_test,y_pred2)
print(class_wise)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       0.97      0.91      0.94        33
#            2       0.91      0.97      0.94        32
#
#     accuracy                           0.96       105
#    macro avg       0.96      0.96      0.96       105
# weighted avg       0.96      0.96      0.96       105

# %%
model3 = SVC(kernel='poly')

# %%
model3
# Out:
# SVC(kernel='poly')

# %%
model_train3 = model3.fit(x_train,y_train)

# %%
model_train3
# Out:
# SVC(kernel='poly')

# %%
y_pred3 =model_train3.predict(x_test)

# %%
y_pred3
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0,
#        1, 2, 0, 1, 2, 0, 2, 2, 1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 0,
#        0, 2, 1, 2, 2, 2, 2, 1, 0, 0, 2, 2, 0, 0, 0, 2, 2])

# %%
i=0
print("\n------------------------------------------------------------------------")
print('%-25s %-25s %-25s' % ('Original Label', 'Predicted Label', 'Correct/Wrong'))
print("--------------------------------------------------------------------------")
for label in y_test:
  print('%-25s' '%-25s' % (label,y_pred3[i]), end=" ")
  if (label == y_pred3[i]):
    print(' %-25s' % ('Correct'))
  else:
    print(' %-25s' % ('Wrong'))
  i = i+1
print("--------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------------
# Original Label            Predicted Label           Correct/Wrong
# --------------------------------------------------------------------------
# 1                        1                          Correct
# 0                        0                          Correct
# 2                        2                          Correct
# 1                        1                          Correct
# 1                        1                          Correct
# 0                        0                          Correct
# 1                        1                          Correct
# 2                        2                          Correct
# 1                        1                          Correct
# 1                        1                          Correct
# 2                        2                          Correct
# 0                        0                          Correct
# ...

# %%
import sklearn.metrics as metrics
confusion = metrics.confusion_matrix (y_test,y_pred3)
confusion
# Out:
# array([[40,  0,  0],
#        [ 0, 29,  4],
#        [ 0,  0, 32]])

# %%
accuracy = accuracy_score(y_test,y_pred3)
accuracy
# Out:
# 0.9619047619047619

# %%
print('Accuracy of the classifier is %0.2f'%metrics.accuracy_score(y_test,y_pred3))
print("---------------------------------------------------------------------")
# Out:
# Accuracy of the classifier is 0.96
# ---------------------------------------------------------------------

# %%
print("\nClassification Report:\n",)
class_wise=metrics.classification_report(y_test,y_pred3)
print(class_wise)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      0.88      0.94        33
#            2       0.89      1.00      0.94        32
#
#     accuracy                           0.96       105
#    macro avg       0.96      0.96      0.96       105
# weighted avg       0.97      0.96      0.96       105

# %%
plt.close();
sns.set_style("whitegrid");
palette={
    0: "red",
    1: "green",
    2: "blue"
}
sns.pairplot(df, hue="species",palette=palette,height=3);
plt.show()
